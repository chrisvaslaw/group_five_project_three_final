# %%
# Dependencies and Setup
import os
import pandas as pd
import datetime
import numpy as np
import requests
import json
from config import gkey
import random

# %%
#house_df = pd.read_csv('static/data/house_df_cleaned.csv')
#house_df

# %%
#read the data sets from resources directory
csv_path = "Resources/zillowdata.csv"
house_df = pd.read_csv(csv_path)

# %%
#read data
house_df
# Out:
#      RegionID  SizeRank                          RegionName RegionType  \
# 0      102001         0                       United States    Country
# 1      394913         1                        New York, NY        Msa
# 2      753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3      394463         3                         Chicago, IL        Msa
# 4      394514         4               Dallas-Fort Worth, TX        Msa
# ..        ...       ...                                 ...        ...
# 905    394767       929                          Lamesa, TX        Msa
# 906    753874       930                           Craig, CO        Msa
# 907    394968       931                           Pecos, TX        Msa
# 908    395188       932                          Vernon, TX        Msa
# 909    394743       933                       Ketchikan, AK        Msa
#
#     StateName  1996-01-31  1996-02-29  1996-03-31  1996-04-30  1996-05-31  \
# ...

# %%
# Target city
target_city = ["New York, NY","United States","Los Angeles-Long Beach-Anaheim, CA","Chicago, IL","Dallas-Fort Worth, TX"]

# Build the endpoint URL
target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(target_city, gkey)

# %%
lat_col = []
lng_col = []
for city in house_df["RegionName"]:
    target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(city, gkey) 
    #print(city)
    geo_data = requests.get(target_url).json()
    #print(geo_data)
    lat = geo_data["results"][0]["geometry"]["location"]["lat"]
    lng = geo_data["results"][0]["geometry"]["location"]["lng"]

# %%
house_df['Lat'] = lat
house_df['Lng'] = lng
house_df
# Out:
#      RegionID  SizeRank                          RegionName RegionType  \
# 0      102001         0                       United States    Country
# 1      394913         1                        New York, NY        Msa
# 2      753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3      394463         3                         Chicago, IL        Msa
# 4      394514         4               Dallas-Fort Worth, TX        Msa
# ..        ...       ...                                 ...        ...
# 905    394767       929                          Lamesa, TX        Msa
# 906    753874       930                           Craig, CO        Msa
# 907    394968       931                           Pecos, TX        Msa
# 908    395188       932                          Vernon, TX        Msa
# 909    394743       933                       Ketchikan, AK        Msa
#
#     StateName  1996-01-31  1996-02-29  1996-03-31  1996-04-30  1996-05-31  \
# ...

# %%
#house_df.head

# %%
lat_col = []
lng_col = []
for city in house_df["RegionName"]:
    target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(city, gkey) 
    geo_data = requests.get(target_url).json()
    lat = geo_data["results"][0]["geometry"]["location"]["lat"]
    lng = geo_data["results"][0]["geometry"]["location"]["lng"]
# Print the json
# print(geo_data)
    lat_col.append(lat)
    lng_col.append(lng)

# %%
target_url
# Out:
# 'https://maps.googleapis.com/maps/api/geocode/json?address=Ketchikan, AK&key=AIzaSyA5bNhkW-flJCV7Rp6xmrOiLvTGt48gEUY'

# %%
# Print the json (pretty printed)
print(json.dumps(geo_data, indent=4, sort_keys=True))
# Out:
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Ketchikan",
#                     "short_name": "Ketchikan",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Ketchikan Gateway",
#                     "short_name": "Ketchikan Gateway",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Alaska",
#                     "short_name": "AK",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
# ...

# %%
geo_data["results"]
# Out:
# [{'address_components': [{'long_name': 'Ketchikan',
#     'short_name': 'Ketchikan',
#     'types': ['locality', 'political']},
#    {'long_name': 'Ketchikan Gateway',
#     'short_name': 'Ketchikan Gateway',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'Alaska',
#     'short_name': 'AK',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']},
#    {'long_name': '99901', 'short_name': '99901', 'types': ['postal_code']}],
#   'formatted_address': 'Ketchikan, AK 99901, USA',
#   'geometry': {'bounds': {'northeast': {'lat': 55.36412300000001,
#      'lng': -131.6149352},
#     'southwest': {'lat': 55.3265269, 'lng': -131.7073381}},
#    'location': {'lat': 55.34222219999999, 'lng': -131.6461112},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 55.36412300000001, 'lng': -131.6149352},
# ...

# %%
house_df
# Out:
#      RegionID  SizeRank                          RegionName RegionType  \
# 0      102001         0                       United States    Country
# 1      394913         1                        New York, NY        Msa
# 2      753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3      394463         3                         Chicago, IL        Msa
# 4      394514         4               Dallas-Fort Worth, TX        Msa
# ..        ...       ...                                 ...        ...
# 905    394767       929                          Lamesa, TX        Msa
# 906    753874       930                           Craig, CO        Msa
# 907    394968       931                           Pecos, TX        Msa
# 908    395188       932                          Vernon, TX        Msa
# 909    394743       933                       Ketchikan, AK        Msa
#
#     StateName  1996-01-31  1996-02-29  1996-03-31  1996-04-30  1996-05-31  \
# ...

# %%
house_df['Lat'] = lat_col
house_df['Lng'] = lng_col
house_df
# Out:
#      RegionID  SizeRank                          RegionName RegionType  \
# 0      102001         0                       United States    Country
# 1      394913         1                        New York, NY        Msa
# 2      753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3      394463         3                         Chicago, IL        Msa
# 4      394514         4               Dallas-Fort Worth, TX        Msa
# ..        ...       ...                                 ...        ...
# 905    394767       929                          Lamesa, TX        Msa
# 906    753874       930                           Craig, CO        Msa
# 907    394968       931                           Pecos, TX        Msa
# 908    395188       932                          Vernon, TX        Msa
# 909    394743       933                       Ketchikan, AK        Msa
#
#     StateName  1996-01-31  1996-02-29  1996-03-31  1996-04-30  1996-05-31  \
# ...

# %%
house_df = pd.melt(house_df, id_vars=['RegionID', 'RegionName','SizeRank','RegionType','StateName', 'Lat', 'Lng'], var_name='Date', value_name='Price')

# %%
house_df['StateName'].fillna('None', inplace=True) #filling NaN values with "None" so US is not accidentally dropped

# %%
house_df
# Out:
#         RegionID                          RegionName  SizeRank RegionType  \
# 0         102001                       United States         0    Country
# 1         394913                        New York, NY         1        Msa
# 2         753899  Los Angeles-Long Beach-Anaheim, CA         2        Msa
# 3         394463                         Chicago, IL         3        Msa
# 4         394514               Dallas-Fort Worth, TX         4        Msa
# ...          ...                                 ...       ...        ...
# 276635    394767                          Lamesa, TX       929        Msa
# 276636    753874                           Craig, CO       930        Msa
# 276637    394968                           Pecos, TX       931        Msa
# 276638    395188                          Vernon, TX       932        Msa
# 276639    394743                       Ketchikan, AK       933        Msa
#
#        StateName        Lat         Lng        Date     Price
# ...

# %%
#check for null values
house_df.isnull().sum()
# Out:
# RegionID          0
# RegionName        0
# SizeRank          0
# RegionType        0
# StateName         0
# Lat               0
# Lng               0
# Date              0
# Price         49037
# dtype: int64

# %%
#drop the null values
house_df = house_df.dropna()

# %%
house_df.isnull().sum()
# Out:
# RegionID      0
# RegionName    0
# SizeRank      0
# RegionType    0
# StateName     0
# Lat           0
# Lng           0
# Date          0
# Price         0
# dtype: int64

# %%
#check data types
house_df.dtypes
# Out:
# RegionID        int64
# RegionName     object
# SizeRank        int64
# RegionType     object
# StateName      object
# Lat           float64
# Lng           float64
# Date           object
# Price         float64
# dtype: object

# %%
#split Date into Year and Month columns 
house_df[['Year','Month',"date"]] = house_df.Date.str.split("-",expand=True)
#split RegionName into State and City columns 
house_df[['City','State']] = house_df.RegionName.str.split(",",expand=True)
house_df
# Out:
# /Users/evrimpolat/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#         RegionID                          RegionName  SizeRank RegionType  \
# 0         102001                       United States         0    Country
# 1         394913                        New York, NY         1        Msa
# 2         753899  Los Angeles-Long Beach-Anaheim, CA         2        Msa
# 3         394463                         Chicago, IL         3        Msa
# 4         394514               Dallas-Fort Worth, TX         4        Msa
# ...          ...                                 ...       ...        ...
# ...

# %%
#adjust the data frame columns
house_df = house_df[['RegionID','State','City','Lat', 'Lng', 'Year', 'Month','Price']]
house_df
# Out:
#         RegionID State                            City        Lat         Lng  \
# 0         102001  None                   United States  37.090240  -95.712891
# 1         394913    NY                        New York  40.712775  -74.005973
# 2         753899    CA  Los Angeles-Long Beach-Anaheim  34.052217 -118.243662
# 3         394463    IL                         Chicago  41.878114  -87.629798
# 4         394514    TX               Dallas-Fort Worth  32.707875  -96.920913
# ...          ...   ...                             ...        ...         ...
# 276635    394767    TX                          Lamesa  32.737600 -101.950992
# 276636    753874    CO                           Craig  40.515249 -107.546454
# 276637    394968    TX                           Pecos  31.422912 -103.493229
# 276638    395188    TX                          Vernon  34.154531  -99.265080
# 276639    394743    AK                       Ketchikan  55.342222 -131.646111
#
#         Year Month     Price
# ...

# %%
house_df.to_csv('static/data/house_df_cleaned.csv', index=False, header=True)

# %%
latest_df = house_df.loc[house_df["Year"]=="2021"]
latest_df
# Out:
#         RegionID State                            City        Lat         Lng  \
# 273000    102001  None                   United States  37.090240  -95.712891
# 273001    394913    NY                        New York  40.712775  -74.005973
# 273002    753899    CA  Los Angeles-Long Beach-Anaheim  34.052217 -118.243662
# 273003    394463    IL                         Chicago  41.878114  -87.629798
# 273004    394514    TX               Dallas-Fort Worth  32.707875  -96.920913
# ...          ...   ...                             ...        ...         ...
# 276635    394767    TX                          Lamesa  32.737600 -101.950992
# 276636    753874    CO                           Craig  40.515249 -107.546454
# 276637    394968    TX                           Pecos  31.422912 -103.493229
# 276638    395188    TX                          Vernon  34.154531  -99.265080
# 276639    394743    AK                       Ketchikan  55.342222 -131.646111
#
#         Year Month     Price
# ...

# %%
latest_df["City"].value_counts()
# Out:
# Columbus                20
# Jackson                 20
# Jacksonville            16
# Athens                  16
# Springfield             16
#                         ..
# Lynchburg                4
# Mankato                  4
# Gardnerville Ranchos     4
# Kansas City              3
# Pittsburgh               3
# Name: City, Length: 817, dtype: int64

# %%
latest_df.head(100)
# Out:
#         RegionID State                            City        Lat         Lng  \
# 273000    102001  None                   United States  37.090240  -95.712891
# 273001    394913    NY                        New York  40.712775  -74.005973
# 273002    753899    CA  Los Angeles-Long Beach-Anaheim  34.052217 -118.243662
# 273003    394463    IL                         Chicago  41.878114  -87.629798
# 273004    394514    TX               Dallas-Fort Worth  32.707875  -96.920913
# ...          ...   ...                             ...        ...         ...
# 273095    395075    PA                        Scranton  41.408969  -75.662412
# 273096    394666    PA                      Harrisburg  40.273191  -76.886701
# 273097    394957    FL                       Melbourne  28.083627  -80.608109
# 273098    394460    TN                     Chattanooga  35.045630  -85.309680
# 273099    395113    WA                         Spokane  47.658780 -117.426046
#
#         Year Month     Price
# ...

# %%
#latest_df = latest_df.reset_index(drop=True)
#latest_df

# %%
top_df = latest_df[["City","State","Price","Lat","Lng"]].sort_values(by="Price", ascending = False)
top_df
# Out:
#                  City State      Price        Lat         Lng
# 275764       San Jose    CA  1364273.0  37.338208 -121.886329
# 274854       San Jose    CA  1351668.0  37.338208 -121.886329
# 273944       San Jose    CA  1350131.0  37.338208 -121.886329
# 273034       San Jose    CA  1345683.0  37.338208 -121.886329
# 275741  San Francisco    CA  1235705.0  37.774929 -122.419415
# ...               ...   ...        ...        ...         ...
# 273817   Forrest City    AR    50321.0  35.008147  -90.789834
# 273876         Helena    AR    29014.0  34.529125  -90.590027
# 274786         Helena    AR    28729.0  34.529125  -90.590027
# 275696         Helena    AR    28623.0  34.529125  -90.590027
# 276606         Helena    AR    28591.0  34.529125  -90.590027
#
# [3638 rows x 5 columns]

# %%
reset = top_df.reset_index(drop=True)

# %%
reset
# Out:
#                City State      Price        Lat         Lng
# 0          San Jose    CA  1364273.0  37.338208 -121.886329
# 1          San Jose    CA  1351668.0  37.338208 -121.886329
# 2          San Jose    CA  1350131.0  37.338208 -121.886329
# 3          San Jose    CA  1345683.0  37.338208 -121.886329
# 4     San Francisco    CA  1235705.0  37.774929 -122.419415
# ...             ...   ...        ...        ...         ...
# 3633   Forrest City    AR    50321.0  35.008147  -90.789834
# 3634         Helena    AR    29014.0  34.529125  -90.590027
# 3635         Helena    AR    28729.0  34.529125  -90.590027
# 3636         Helena    AR    28623.0  34.529125  -90.590027
# 3637         Helena    AR    28591.0  34.529125  -90.590027
#
# [3638 rows x 5 columns]

# %%
top_df_2 = reset.iloc[0:51]
top_df_2
# Out:
#                               City State      Price        Lat         Lng
# 0                         San Jose    CA  1364273.0  37.338208 -121.886329
# 1                         San Jose    CA  1351668.0  37.338208 -121.886329
# 2                         San Jose    CA  1350131.0  37.338208 -121.886329
# 3                         San Jose    CA  1345683.0  37.338208 -121.886329
# 4                    San Francisco    CA  1235705.0  37.774929 -122.419415
# 5                    San Francisco    CA  1217058.0  37.774929 -122.419415
# 6                    San Francisco    CA  1206154.0  37.774929 -122.419415
# 7                    San Francisco    CA  1196778.0  37.774929 -122.419415
# 8                       Santa Cruz    CA  1005082.0  36.974117 -122.030796
# 9                       Santa Cruz    CA   986346.0  36.974117 -122.030796
# 10                      Santa Cruz    CA   973371.0  36.974117 -122.030796
# ...

# %%
bottom_df = reset.iloc[-51:-1]
bottom_df
# Out:
#                 City State    Price        Lat         Lng
# 3587      Pine Bluff    AR  67612.0  34.228431  -92.003195
# 3588           Altus    OK  67502.0  34.637765  -99.334044
# 3589      Pine Bluff    AR  67287.0  34.228431  -92.003195
# 3590           Pampa    TX  65199.0  35.536156 -100.959871
# 3591           Pampa    TX  64784.0  35.536156 -100.959871
# 3592           Pampa    TX  64391.0  35.536156 -100.959871
# 3593           Pampa    TX  64061.0  35.536156 -100.959871
# 3594       Greenwood    MS  63553.0  33.516232  -90.179528
# 3595       Greenwood    MS  62923.0  33.516232  -90.179528
# 3596     Coffeyville    KS  62100.0  37.037301  -95.616366
# 3597       Greenwood    MS  62027.0  33.516232  -90.179528
# 3598     Coffeyville    KS  61860.0  37.037301  -95.616366
# 3599     Coffeyville    KS  61594.0  37.037301  -95.616366
# 3600     Blytheville    AR  61463.0  35.927295  -89.918975
# 3601     Coffeyville    KS  61201.0  37.037301  -95.616366
# ...

# %%
bottom_df.index
# Out:
# RangeIndex(start=3587, stop=3637, step=1)

# %%
city_groupby_avgprice = reset.groupby(["City","State"]).mean()
city_groupby_avgprice
# Out:
#                       Price        Lat         Lng
# City       State
# Aberdeen    SD    177447.25  45.464698  -98.486483
#             WA    252607.00  46.975371 -123.815722
# Abilene     TX    147235.00  32.448736  -99.733144
# Ada         OK    107086.00  34.774531  -96.678345
# Adrian      MI    171483.25  41.897547  -84.037166
# ...                     ...        ...         ...
# Youngstown  OH    116084.50  41.099780  -80.649519
# Yuba City   CA    348884.25  39.140448 -121.616911
# Yuma        AZ    195095.00  32.692651 -114.627692
# Zanesville  OH    132214.75  39.940345  -82.013192
# Zapata      TX    101366.00  26.907260  -99.271425
#
# [909 rows x 3 columns]

# %%
cities = list(list(zip(*list(city_groupby_avgprice.index)))[0])
states = list(list(zip(*list(city_groupby_avgprice.index)))[1])
city_groupby_avgprice["City"] = cities
city_groupby_avgprice["State"] = states
clean_df = city_groupby_avgprice.sort_values(by="Price", ascending = False).reset_index(drop=True)
clean_df
# Out:
#           Price        Lat         Lng            City State
# 0    1352938.75  37.338208 -121.886329        San Jose    CA
# 1    1213923.75  37.774929 -122.419415   San Francisco    CA
# 2     982293.50  36.974117 -122.030796      Santa Cruz    CA
# 3     912183.50  41.454279  -70.603639  Vineyard Haven    MA
# 4     844873.50  40.745712 -111.613141     Summit Park    UT
# ..          ...        ...         ...             ...   ...
# 904    56838.50  33.584558  -92.834329          Camden    AR
# 905    56366.00  32.756246  -91.872350         Bastrop    LA
# 906    51828.50  34.617380  -79.684781   Bennettsville    SC
# 907    50812.00  35.008147  -90.789834    Forrest City    AR
# 908    28739.25  34.529125  -90.590027          Helena    AR
#
# [909 rows x 5 columns]

# %%
clean_df.to_csv('static/data/clean_cities.csv', index=False, header=True)
